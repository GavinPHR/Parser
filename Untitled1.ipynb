# %%
import config
config.load()

# %%
len(config.pcfg.rule3s)
# Out:
# 12744

# %%
config.pcfg.rule3s
# Out:
# Counter({NP|<>-3->DT-1 NNP-1: 0.14584887699709279,
#          NP|<>-1->NP|<>-3 CD-0: 0.01769302907158487,
#          NP-10->NP|<>-1 NN-1: 0.10821896198138507,
#          NP-5->DT-2 NN-1: 0.7744985136184687,
#          NP|<>-4->`` NP-5: 0.0004900213827512474,
#          NP|<>-1->NP|<>-4 '': 0.01419193497968115,
#          NP-6->NNP-0 POS-0: 0.16607340841454163,
#          NP|<>-2->NP-6 NNP-1: 0.010245042238332036,
#          NP-1->NP|<>-2 NNP-0: 0.005264468395404261,
#          PP-2->IN-2 NP-1: 0.12338234875849712,
#          NP-1->NP|<>-1 PP-2: 0.005122185465798741,
#          PP-0->IN-1 NP-1: 0.039362314076752405,
#          NP|<>-2->NP-10 PP-0: 0.038643580372655924,
#          PRN|<>->-LRB- ``: 0.008415147265077139,
#          NP-11->VBN-0 NNS-0: 0.006542189962274963,
#          VP|<>-2->VBP NP-5: 0.003232910087616549,
#          NP-6->NNP-0 NNP-0: 0.6704790803524537,
#          PP-3->IN-0 NP-6: 0.006943076620051211,
#          VP-0->VP|<>-2 PP-3: 0.12609991739395898,
# ...

# %%
k = set()
for rule in config.pcfg.rule3s:
    if 'NP-' in config.nonterminal_map[rule.a]:
        k.add(rule)

# %%
k
# Out:
# {NP-0-0-0-1-0-1->NP|<>-0-1-1-0-0-0 NN-1-1-0-1,
#  NP-0-0-0-1-1->NP|<>-0-1-1-1-0-0 NN-1-1-0-1,
#  NP-0-0-0-1-0-1->NP|<>-0-1-1-0-0-1 NN-1-1-0-1,
#  NP-0-0-0-1-0-1->NP|<>-0-1-1-0-0-1 NP-0-0-0-1-0-1,
#  NP-0-0-0-0-0-1->NP|<>-0-1-1-0-1 NN-1-1-0-1,
#  NP-1-0-1-0-0-0->DT-0-0-0-0-0-0 NN-1-0-0-1-0-1,
#  NP-0-0-1-0-0->NP|<>-0-0-1-1-0-0 NP-0-0-0-1-0-1,
#  NP-1-0-1-0-0-1->DT-0-0-0-0-0-0 NN-1-0-0-1-0-1,
#  NP-0-0-0-1-0-0->NP|<>-0-1-1-0-0-1 NN-1-1-0-1,
#  NP-0-0-1-1-0->NP|<>-0-0-0-0-1-1 '',
#  NP-0-0-1-0-1->NP|<>-0-0-1-0 NP-0-0-0-1-0-1,
#  NP-1-1-0-0-1-0->NNP-0-0-0-0-1 NNP-0-0-0-0-0-0,
#  NP-1-1-0-0-1-1->NNP-0-0-0-0-0-0 POS-0-0,
#  NP-1-1-0-0-1-1->NNP-0-0-0-0-0-0 NNP-0-0-0-0-0-0,
#  NP-0-0-1-0-1->NP|<>-0-0-1-0 NP-1-1-0-0-1-1,
#  NP-0-0-0-1-0-0->NP|<>-0-1-1-0-0-1 NP-1-1-0-0-1-1,
#  NP-0-0-1-1-0->NP|<>-0-0-0-0-1-0 NNP-0-1,
#  NP-0-0-0-0-0-0->NP|<>-0-1-1-0-1 NNP-0-1,
#  NP-0-0-1-1-1-0->NP|<>-0-0-0-0-1-0 NNP-0-1,
#  NP-0-0-1-1-1-1->NP|<>-0-0-0-0-0-0 PP-1-0-0-1-1-0,
# ...
