# %%
from nltk.tree import Tree
with open('../../Downloads/baseline_parse.txt', 'r') as f:
    test = [Tree.fromstring(x) for x in f]
for tree in test:
    tree.chomsky_normal_form(factor='left', horzMarkov=0)

# %%
test[498]
# Out:
# Tree('S', [Tree('S|<>', [Tree('NP', [Tree('NP|<>', [Tree('NP|<>', [Tree('NP', [Tree('NP|<>', [Tree('NNP', ['SPRUCING']), Tree('NNP', ['UP'])]), Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP', [Tree('NP|<>', [Tree('NP', [Tree('DT', ['THE']), Tree('NNP', ['DIGS'])]), Tree(':', [':'])]), Tree('NP', [Tree('QP', [Tree('IN', ['About']), Tree('CD', ['200'])]), Tree('NNS', ['employees'])])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP|<>', [Tree('DT', ['the']), Tree('NNP', ['Maryland'])]), Tree('NNP', ['Department'])])])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('NP|<>', [Tree('NP|<>', [Tree('JJ', ['Economic']), Tree('CC', ['and'])]), Tree('NN', ['Employment'])]), Tree('NN', ['Development'])])])]), Tree('PP', [Tree('IN', ['for']), Tree('NP', [Tree('NP', [Tree('CD', ['four']), Tree('NNS', ['months'])]), Tree('NP', [Tree('VBN', ['painted']), Tree('NNS', ['walls'])])])])])]), Tree(',', [','])]), Tree('NP', [Tree('ADJP', [Tree('ADJP|<>', [Tree('JJ', ['polished']), Tree('CC', [
# ...

# %%
from nltk.tag.stanford import StanfordPOSTagger
tagger = StanfordPOSTagger('./parsing/english-bidirectional-distsim.tagger', path_to_jar='parsing/stanford-postagger.jar')

# %%
tagger.tag(test[498].leaves())
# Out:
# [('SPRUCING', 'NNP'),
#  ('UP', 'NNP'),
#  ('THE', 'NNP'),
#  ('DIGS', 'NNP'),
#  (':', ':'),
#  ('About', 'RB'),
#  ('200', 'CD'),
#  ('employees', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Maryland', 'NNP'),
#  ('Department', 'NNP'),
#  ('of', 'IN'),
#  ('Economic', 'NNP'),
#  ('and', 'CC'),
#  ('Employment', 'NNP'),
#  ('Development', 'NNP'),
#  ('for', 'IN'),
#  ('four', 'CD'),
#  ('months', 'NNS'),
#  ('painted', 'VBN'),
#  ('walls', 'NNS'),
#  (',', ','),
#  ('polished', 'JJ'),
#  ('and', 'CC'),
#  ('carpeted', 'JJ'),
#  ('floors', 'NNS'),
#  (',', ','),
#  ('bought', 'VBD'),
#  ('plants', 'NNS'),
#  (',', ','),
#  ('cleaned', 'VBN'),
#  ('windows', 'NNS'),
#  ('and', 'CC'),
#  ('blinds', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('hung', 'VBD'),
#  ('pictures', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('agency', 'NN'),
#  ("'s", 'POS'),
#  ('Baltimore', 'NNP'),
#  ('office', 'NN'),
#  ('.', '.')]

# %%
# !pwd
# Out:
# /Users/phr/Desktop/Parser
